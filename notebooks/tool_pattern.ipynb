# %% [markdown]
# # Tool Pattern

# %% [markdown]
# <img src="../img/tool_pattern.png" alt="Alt text" width="800"/>
#
# ---
#
# As you may already know, the information stored in LLM weights is (usually) 𝐧𝐨𝐭 𝐞𝐧𝐨𝐮𝐠𝐡 to give accurate and insightful answers to our questions.
#
# That's why we need to provide the LLM with ways to access the outside world. 🌍
#
# In practice, you can build tools for whatever you want (at the end of the day they are just functions the LLM can use), from a tool that let's you access Wikipedia, another to analyse the content of YouTube videos or calculate difficult integrals using Wolfram Alpha.
#
# The second pattern we are going to implement is the **tool pattern**.
#
# In this notebook, you'll learn how **tools** actually work. This is the **second lesson** of the "Agentic Patterns from Scratch" series. Take a look at the first lesson if you haven't!
#
# * [First Lesson: The Reflection Pattern](https://github.com/neural-maze/agentic_patterns/blob/main/notebooks/reflection_pattern.ipynb)

# %% [markdown]
# ## A simple function

# %% [markdown]
# Take a look at this function 👇

# %%
import json

def get_current_weather(location: str, unit: str):
	"""
	Get the current weather in a given location

	location (str): The city and state, e.g. Madrid, Barcelona
	unit (str): The unit. It can take two values; "celsius", "fahrenheit"
	"""
	if location == "Madrid":
		return json.dumps({"temperature": 25, "unit": unit})

	else:
		return json.dumps({"temperature": 58, "unit": unit})

# %% [markdown]
# Very simple, right? You provide a `location` and a `unit` and it returns the temperature.

# %%
get_current_weather(location="Madrid", unit="celsius")
# Out:
# '{"temperature": 25, "unit": "celsius"}'

# %% [markdown]
# But the question is:
#
# **How can you make this function available to an LLM?**
#
# An LLM is a type of NLP system, so it expects text as input. But how can we transform this function into text?

# %% [markdown]
# ## A System Prompt that works

# %% [markdown]
# For the LLM to be aware of this function, we need to provide some relevant information about it in the context. **I'm referring to the function name, attributes, description, etc.** Take a look at the following System Prompt.

# %% [markdown]
# ```xml
# You are a function calling AI model. You are provided with function signatures within <tools></tools> XML tags.
# You may call one or more functions to assist with the user query. Don't make assumptions about what values to plug
# into functions. Pay special attention to the properties 'types'. You should use those types as in a Python dict.
# For each function call return a json object with function name and arguments within <tool_call></tool_call> XML tags as follows:
#
# <tool_call>
# {"name": <function-name>,"arguments": <args-dict>}
# </tool_call>
#
# Here are the available tools:
#
# <tools> {
#     "name": "get_current_weather",
#     "description": "Get the current weather in a given location location (str): The city and state, e.g. Madrid, Barcelona unit (str): The unit. It can take two values; 'celsius', 'fahrenheit'",
#     "parameters": {
#         "properties": {
#             "location": {
#                 "type": "string"
#             },
#             "unit": {
#                 "type": "string"
#             }
#         }
#     }
# }
# </tools>
# ```
#
#
# As you can see, the LLM enforces the LLM to behave as a `function calling AI model` who, given a list of function signatures inside the <tools></tools> XML tags
# will select which one to use. When the model decides a function to use, it will return a json like the following, representing a function call:
#
# ```xml
# <tool_call>
# {"name": <function-name>,"arguments": <args-dict>}
# </tool_call>
# ```

# %% [markdown]
# Let's see how it works in practise! 👇

# %%
import os
import re
from groq import Groq
from dotenv import load_dotenv

# Remember to load the environment variables. You should have the Groq API Key in there :)
load_dotenv()

#MODEL = "openai/gpt-oss-120b"
MODEL = "meta-llama/llama-4-scout-17b-16e-instruct"
#MODEL = "openai/gpt-oss-20b"
#MODEL = "qwen/qwen3-32b"
GROQ_CLIENT = Groq()

# Define the System Prompt as a constant
TOOL_SYSTEM_PROMPT = """
You are a function calling AI model. You are provided with function signatures within <tools></tools> XML tags. 
You may call one or more functions to assist with the user query. Don't make assumptions about what values to plug 
into functions. Pay special attention to the properties 'types'. You should use those types as in a Python dict.
For each function call return a json object with function name and arguments within <tool_call></tool_call> XML tags as follows:

<tool_call>
{"name": <function-name>,"arguments": <args-dict>}
</tool_call>

Here are the available tools:

<tools> {
    "name": "get_current_weather",
    "description": "Get the current weather in a given location location (str): The city and state, e.g. Madrid, Barcelona unit (str): The unit. It can take two values; 'celsius', 'fahrenheit'",
    "parameters": {
        "properties": {
            "location": {
                "type": "str"
            },
            "unit": {
                "type": "str"
            }
        }
    }
}
</tools>
"""

# %% [markdown]
# Let's ask a very simple question: `"What's the current temperature in Madrid, in Celsius?"` This step is only to extract a tool call

# %%
tool_chat_history = [
    {
        "role": "system",
        "content": TOOL_SYSTEM_PROMPT
    }
]
agent_chat_history = []

user_msg = {
    "role": "user",
    "content": "What's the current temperature in Madrid, in Celsius?"
}

tool_chat_history.append(user_msg)
agent_chat_history.append(user_msg)

# this step is to extract a tool call
output = GROQ_CLIENT.chat.completions.create(
    messages=tool_chat_history,
    model=MODEL
).choices[0].message.content

print(output)
# Out:
# <tool_calls>
# {"name": "get_current_weather","arguments": {"location": "Madrid", "unit": "celsius"}}
# </tool_calls>

# %% [markdown]
# ---
#
# **That's an improvement!** We may not have the *proper* answer but, with this information, we can obtain it! How? Well, we just need to:
#
# 1. Parse the LLM output. By this I mean deleting the XML tags
# 2. Load the output as a proper Python dict
#
# The function below does exactly this.
#
# ---

# %%
def parse_tool_call_str(tool_call_str: str):
    pattern = r'</?tool_call[s]?>'
    clean_tags = re.sub(pattern, '', tool_call_str)
    
    try:
        tool_call_json = json.loads(clean_tags)
        return tool_call_json
    except json.JSONDecodeError:
        return clean_tags
    except Exception as e:
        print(f"Unexpected error: {e}")
        return "There was some error parsing the Tool's output"

# %% [markdown]
# This step is to actually extract exact tool name with the parameters

# %%
parsed_output = parse_tool_call_str(output)
parsed_output
# Out:
# {'name': 'get_current_weather', 'arguments': {'location': 'Madrid', 'unit': 'celsius'}}

# %% [markdown]
# We can simply run the function now, by passing the arguments like this 👇

# %%
result = get_current_weather(**parsed_output["arguments"])

# %%
result
# Out:
# '{"temperature": 25, "unit": "celsius"}'

# %% [markdown]
# **That's it!** A temperature of 25 degrees Celsius.
#
# As you can see, we're dealing with a string, so we can simply add the parsed_output to the `chat_history` so that the LLM knows the information it has to return to the user. This step is to actually ask model to compose answer based on a) initial ask from the user and b) result of the tool call

# %%
agent_chat_history.append({
    "role": "user",
    "content": f"Observation: {result}"
})

# %%
print(tool_chat_history)
print(agent_chat_history)
# Out:
# [{'role': 'system', 'content': '\nYou are a function calling AI model. You are provided with function signatures within <tools></tools> XML tags. \nYou may call one or more functions to assist with the user query. Don\'t make assumptions about what values to plug \ninto functions. Pay special attention to the properties \'types\'. You should use those types as in a Python dict.\nFor each function call return a json object with function name and arguments within <tool_call></tool_call> XML tags as follows:\n\n<tool_call>\n{"name": <function-name>,"arguments": <args-dict>}\n</tool_call>\n\nHere are the available tools:\n\n<tools> {\n    "name": "get_current_weather",\n    "description": "Get the current weather in a given location location (str): The city and state, e.g. Madrid, Barcelona unit (str): The unit. It can take two values; \'celsius\', \'fahrenheit\'",\n    "parameters": {\n        "properties": {\n            "location": {\n                "type": "str"\n            },\n            "unit": {\n                "type": "str"\n            }\n        }\n    }\n}\n</tools>\n'}, {'role': 'user', 'content': "What's the current temperature in Madrid, in Celsius?"}]
# [{'role': 'user', 'content': "What's the current temperature in Madrid, in Celsius?"}, {'role': 'user', 'content': 'Observation: {"temperature": 25, "unit": "celsius"}'}, {'role': 'user', 'content': 'Observation: {"temperature": 25, "unit": "celsius"}'}, {'role': 'user', 'content': 'Observation: {"temperature": 25, "unit": "celsius"}'}]

# %%
GROQ_CLIENT.chat.completions.create(
    messages=agent_chat_history,
    model=MODEL
).choices[0].message.content
# Out:
# 'The current temperature in Madrid is 25°C.'

# %% [markdown]
# ## Implementing everything the good way

# %% [markdown]
# To recap, we have a way for the LLM to generate `tool_calls` that we can use later to *properly* run the functions. But, as you may imagine, there are some pieces missing:
#
# 1. We need to automatically transform any function into a description like we saw in the initial system prompt.
# 2. We need a way to tell the agent that this function is a tool
#
# Let's do it!

# %% [markdown]
# ### The `tool` decorator

# %% [markdown]
# We are going to use the `tool` decorator to transform any Python function into a tool. You can see the implementation [here](https://github.com/neural-maze/agentic_patterns/blob/main/src/agentic_patterns/tool_pattern/tool.py). To test it out, let's make a more complex tool than before. For example, a tool that interacts with [Hacker News](https://news.ycombinator.com/), getting the current top stories.
#
# > Reminder: To automatically generate the function signature for the tool, we need a way to infer the arguments types. For this reason, we need to create the typing annotations.

# %%
import json
import requests
from agentic_patterns.tool_pattern.tool import tool
from agentic_patterns.tool_pattern.tool_agent import ToolAgent

def fetch_top_hacker_news_stories(top_n: int):
    """
    Fetch the top stories from Hacker News.

    This function retrieves the top `top_n` stories from Hacker News using the Hacker News API. 
    Each story contains the title, URL, score, author, and time of submission. The data is fetched 
    from the official Firebase Hacker News API, which returns story details in JSON format.

    Args:
        top_n (int): The number of top stories to retrieve.
    """
    top_stories_url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
    
    try:
        response = requests.get(top_stories_url)
        response.raise_for_status()  # Check for HTTP errors
        
        # Get the top story IDs
        top_story_ids = response.json()[:top_n]
        
        top_stories = []
        
        # For each story ID, fetch the story details
        for story_id in top_story_ids:
            story_url = f'https://hacker-news.firebaseio.com/v0/item/{story_id}.json'
            story_response = requests.get(story_url)
            story_response.raise_for_status()  # Check for HTTP errors
            story_data = story_response.json()
            
            # Append the story title and URL (or other relevant info) to the list
            top_stories.append({
                'title': story_data.get('title', 'No title'),
                'url': story_data.get('url', 'No URL available'),
            })
        
        return json.dumps(top_stories)

    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return []

# %% [markdown]
# If we run this Python function, we'll obtain the top HN stories, as you can see below (the top 5 in this case).

# %%
json.loads(fetch_top_hacker_news_stories(top_n=5))
# Out:
# [{'title': 'Rock Tumbler Instructions: Turning Rough Rocks into Beautiful Tumbled Stones', 'url': 'https://rocktumbler.com/tips/rock-tumbler-instructions/'}, {'title': 'The Journey Before main()', 'url': 'https://amit.prasad.me/blog/before-main'}, {'title': 'Making a micro Linux distro (2023)', 'url': 'https://popovicu.com/posts/making-a-micro-linux-distro/'}, {'title': 'Jacqueline – A minimal i386 kernel written in Pascal', 'url': 'https://github.com/danirod/jacqueline'}, {'title': 'The future of Python web services looks GIL-free', 'url': 'https://blog.baro.dev/p/the-future-of-python-web-services-looks-gil-free'}]

# %% [markdown]
# To transform the `fetch_top_hacker_news_stories` function into a Tool, we can use the `tool` decorator.

# %%
hn_tool = tool(fetch_top_hacker_news_stories)

# %% [markdown]
# The Tool has the following parameters: a `name`, a `fn_signature` and the `fn` (this is the function we are going to call, this case `fetch_top_hacker_news_stories`)

# %%
hn_tool.name
# Out:
# 'fetch_top_hacker_news_stories'

# %% [markdown]
# By default, the tool gets its name from the function name.

# %%
json.loads(hn_tool.fn_signature)
# Out:
# {'name': 'fetch_top_hacker_news_stories', 'description': '\n    Fetch the top stories from Hacker News.\n\n    This function retrieves the top `top_n` stories from Hacker News using the Hacker News API. \n    Each story contains the title, URL, score, author, and time of submission. The data is fetched \n    from the official Firebase Hacker News API, which returns story details in JSON format.\n\n    Args:\n        top_n (int): The number of top stories to retrieve.\n    ', 'parameters': {'properties': {'top_n': {'type': 'int'}}}}

# %% [markdown]
# As you can see, the function signature has been automatically generated. It contains the `name`, a `description` (taken from the docstrings) and the `parameters`, whose types come from the tying annotations. Now that we have a tool, let's run the agent.

# %% [markdown]
# ### The `ToolAgent`

# %% [markdown]
# To create the agent, we just need to pass a list of tools (in this case, just one).

# %%
#MODEL = "openai/gpt-oss-120b"
#MODEL = "meta-llama/llama-4-scout-17b-16e-instruct"
#MODEL = "openai/gpt-oss-20b"
#MODEL = "qwen/qwen3-32b"
MODEL = "moonshotai/kimi-k2-instruct-0905"

# %%
tool_agent = ToolAgent(tools=[hn_tool],  model = MODEL)

# %% [markdown]
# A quick check to see that everything works fine. If we ask the agent something unrelated to Hacker News, it shouldn't use the tool.

# %%
output = tool_agent.run(user_msg="Tell me your name")

# %%
print(output)
# Out:
# I’m ChatGPT, an AI language model created by OpenAI. How can I help you today?

# %% [markdown]
# Now, let's ask for specific information about Hacker News.

# %%
output = tool_agent.run(user_msg="Tell me the top 5 Hacker News stories right now")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 output = tool_agent.run(user_msg="Tell me the top 5 Hacker News stories right now")
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/agentic_patterns/tool_pattern/tool_agent.py:139, in ToolAgent.run(self, user_msg)
#     134     observations = self.process_tool_calls(tool_calls.content)
#     135     update_chat_history(
#     136         agent_chat_history, f'f"Observation: {observations}"', "user"
#     137     )
# --> 139 return completions_create(self.client, agent_chat_history, self.model)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/agentic_patterns/utils/completions.py:13, in completions_create(client, messages, model)
#       1 def completions_create(client, messages: list, model: str) -> str:
#       2     """
#       3     Sends a request to the client's `completions.create` method to interact with the language model.
#       4
#    (...)     11         str: The content of the model's response.
#      12     """
# ---> 13     response = client.chat.completions.create(messages=messages, model=model)
#      14     return str(response.choices[0].message.content)
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/groq/resources/chat/completions.py:289, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     148 def create(
#     149     self,
#     150     *,
#    (...)    177     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     178 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     179     """
#     180     Creates a model response for the given chat conversation.
#     181
#    (...)    287       timeout: Override the client-level default timeout for this request, in seconds
#     288     """
# --> 289     return self._post(
#     290         "/openai/v1/chat/completions",
#     291         body=maybe_transform(
#     292             {
#     293                 "messages": messages,
#     294                 "model": model,
#     295                 "frequency_penalty": frequency_penalty,
#     296                 "function_call": function_call,
#     297                 "functions": functions,
#     298                 "logit_bias": logit_bias,
#     299                 "logprobs": logprobs,
#     300                 "max_tokens": max_tokens,
#     301                 "n": n,
#     302                 "parallel_tool_calls": parallel_tool_calls,
#     303                 "presence_penalty": presence_penalty,
#     304                 "response_format": response_format,
#     305                 "seed": seed,
#     306                 "stop": stop,
#     307                 "stream": stream,
#     308                 "temperature": temperature,
#     309                 "tool_choice": tool_choice,
#     310                 "tools": tools,
#     311                 "top_logprobs": top_logprobs,
#     312                 "top_p": top_p,
#     313                 "user": user,
#     314             },
#     315             completion_create_params.CompletionCreateParams,
#     316         ),
#     317         options=make_request_options(
#     318             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     319         ),
#     320         cast_to=ChatCompletion,
#     321         stream=stream or False,
#     322         stream_cls=Stream[ChatCompletionChunk],
#     323     )
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/groq/_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)   1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/groq/_base_client.py:920, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     911 def request(
#     912     self,
#     913     cast_to: Type[ResponseT],
#    (...)    918     stream_cls: type[_StreamT] | None = None,
#     919 ) -> ResponseT | _StreamT:
# --> 920     return self._request(
#     921         cast_to=cast_to,
#     922         options=options,
#     923         stream=stream,
#     924         stream_cls=stream_cls,
#     925         remaining_retries=remaining_retries,
#     926     )
#
# File ~/.pyenv/versions/3.11.8/lib/python3.11/site-packages/groq/_base_client.py:1018, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1015         err.response.read()
#    1017     log.debug("Re-raising status error")
# -> 1018     raise self._make_status_error_from_response(err.response) from None
#    1020 return self._process_response(
#    1021     cast_to=cast_to,
#    1022     options=options,
#    (...)   1025     stream_cls=stream_cls,
#    1026 )
#
# BadRequestError: Error code: 400 - {'error': {'message': 'Tool choice is none, but model called a tool', 'type': 'invalid_request_error', 'code': 'tool_use_failed', 'failed_generation': '{"name": "browser.open", "arguments": {"cursor": 0, "id": "https://news.ycombinator.com/"}}'}}

# %%
print(output)
# Out:
# Here are the top 5 Hacker News stories at the moment:
#
# 1. **The Journey Before main()**
#    [amit.prasad.me](https://amit.prasad.me/blog/before-main)
#
# 2. **Rock Tumbler Instructions: Turning Rough Rocks into Beautiful Tumbled Stones**
#    [rocktumbler.com](https://rocktumbler.com/tips/rock-tumbler-instructions/)
#
# 3. **Making a micro Linux distro (2023)**
#    [popovicu.com](https://popovicu.com/posts/making-a-micro-linux-distro/)
#
# 4. **Jacqueline – A minimal i386 kernel written in Pascal (2019)**
#    [GitHub](https://github.com/danirod/jacqueline)
#
# 5. **Against SQL**
#    [scattered-thoughts.net](https://www.scattered-thoughts.net/writing/against-sql/)

# %% [markdown]
# ---
# There you have it!! A fully functional Tool!! 🛠️
